# %%
import pandas as pd
import numpy as np
import requests

# %%
url = "https://api.test.datacite.org/events"

headers = {'accept': 'application/vnd.api+json'}

response = requests.request("GET", url, headers=headers)

print(response.json())
# Out:
# {'data': [{'id': 'd04a4c7a-2f19-4002-b8e7-06a844b5716f', 'type': 'events', 'attributes': {'subj-id': 'https://api.test.datacite.org/reports/a8025c2b-ae9f-48d8-8dc3-d1133fff1502', 'obj-id': 'https://doi.org/10.6073/pasta/aec48ca27decb1fd2c2f454f1c5f88e4', 'source-id': 'datacite-usage', 'relation-type-id': 'total-dataset-requests-regular', 'total': 349, 'message-action': 'create', 'source-token': '43ba99ae-5cf0-11e8-9c2d-fa7ae01bbebc', 'license': 'https://creativecommons.org/publicdomain/zero/1.0/', 'occurred-at': '2018-05-22T00:00:00.000Z', 'timestamp': '2018-09-05T18:20:15.842Z'}, 'relationships': {'subj': {'data': {'id': 'https://api.test.datacite.org/reports/a8025c2b-ae9f-48d8-8dc3-d1133fff1502', 'type': 'objects'}}, 'obj': {'data': {'id': 'https://doi.org/10.6073/pasta/aec48ca27decb1fd2c2f454f1c5f88e4', 'type': 'objects'}}}}, {'id': '3e604437-5cc8-4d1f-9d8f-bb421ab89d2a', 'type': 'events', 'attributes': {'subj-id': 'https://api.test.datacite.org/reports/a8025c2b-ae9f-48d8-8dc3-d11
# ...

# %%
response.json()
# Out:
# {'reports': [{'id': '006948cd-d46c-4cc1-83e5-95b82dd5576a',
#    'report-header': {'report-name': 'Dataset Master Report',
#     'report-id': 'dsr',
#     'release': 'rd1',
#     'created-by': 'urn:node:PISCO',
#     'created': '2019-05-23',
#     'reporting-period': {'end-date': '2017-07-31', 'begin-date': '2017-07-01'},
#     'report-filters': [],
#     'report-attributes': [],
#     'exceptions': [{'code': 69,
#       'data': 'usage data needs to be uncompressed',
#       'message': 'Report is compressed using gzip',
#       'help-url': 'https://github.com/datacite/sashimi',
#       'severity': 'warning'}]}},
#   {'id': '00b5ace7-e520-4348-820d-908ad9f8fb76',
#    'report-header': {'report-name': 'Dataset Master Report',
#     'report-id': 'dsr',
#     'release': 'rd1',
#     'created-by': 'urn:node:mnUCSB1',
#     'created': '2019-05-23',
#     'reporting-period': {'end-date': '2017-09-30', 'begin-date': '2017-09-01'},
#     'report-filters': [],
#     'report-attributes': [],
# ...
